# %% [markdown]
# # Load Necessary Libraries

# %%
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# # Load the webpage content

# %%
r = requests.get("https://www.ebay.ie/sch/i.html?_from=R40&_trksid=p2334524.m570.l1313&_nkw=monitors&_sacat=0&LH_TitleDesc=0&_odkw=server&_osacat=0.html")

# %% [markdown]
# # Convert to a beautifulsoup object

# %%
soup = bs(r.content)
#printout the html
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]><html class="ie9 srp-ds6" lang="en"><![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="srp-ds6" lang="en">
#  <!--<![endif]-->
#  <!--M#s0-1-->
#  <body>
#   <noscript class="x-page-config">
#   </noscript>
#   <!--M/-->
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script>
# ...

# %%
findmonitorDELL= soup.find_all("span")
print(findmonitorDELL)
# Out:
# [<span aria-label="Busy" class="progress-spinner progress-spinner--large s-progressive-spinner" role="img"><!--M#s0-10-0-1-0--><svg aria-hidden="true" class="icon icon--spinner-large" focusable="false"><defs data-marko-key="@defs s0-10-0-1-0"><symbol fill="none" id="icon-spinner-large" viewbox="0 0 24 24"><path clip-rule="evenodd" d="M12 2C10.0222 2 8.08879 2.58649 6.4443 3.6853C4.79981 4.78412 3.51809 6.3459 2.76121 8.17317C2.00433 10.0004 1.8063 12.0111 2.19215 13.9509C2.578 15.8907 3.53041 17.6725 4.92894 19.0711C6.32746 20.4696 8.10929 21.422 10.0491 21.8079C11.9889 22.1937 13.9996 21.9957 15.8268 21.2388C17.6541 20.4819 19.2159 19.2002 20.3147 17.5557C21.4135 15.9112 22 13.9778 22 12C22 11.4477 22.4477 11 23 11C23.5523 11 24 11.4477 24 12C24 14.3734 23.2962 16.6935 21.9776 18.6668C20.6591 20.6402 18.7849 22.1783 16.5922 23.0866C14.3995 23.9948 11.9867 24.2324 9.65892 23.7694C7.33115 23.3064 5.19295 22.1635 3.51472 20.4853C1.83649 18.8071 0.693605 16.6689 0.230582 14.3411C-0.2324
# ...

# %%
#Passing a list of elements
